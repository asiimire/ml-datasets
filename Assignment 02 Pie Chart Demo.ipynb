# %%
#import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#view the plot in jupyter notebook
# %matplotlib inline

# %%
#create two lists, one for cause and the other for percentile.
#data from ohio state, leading causes of death in the state from year 2012
#cause of death
cause ='Chronic diseases','Unintentional Injuries','Alzheimiers','Infulenza and Pneumonia','Sepsis','Others'
#percentile
percentile=[62,5,4,2,1,26]

# %%
#set the piechart plot properties
#set the figure size
plt.figure(figsize=(10,10))
#explode the largest slice in the pie chart
explode=(0.05,0,0,0,0,0)
#set the piechart properties
#autopct will embed the percentile value to each slice of the pie
plt.pie(percentile,labels=cause, explode=explode,autopct='%1.f%%',startangle=70)
#use axis equal to draw the pie as a circle
plt.axis('equal')
#set the title of the piechart
plt.title('Ohio state - 2012: Leading causes of death')
#show the plot(piechart)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
